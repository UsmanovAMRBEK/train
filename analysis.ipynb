# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("country_level_data.csv")
data
# Out:
#     region_id  country_name           gdp  \
# 0         LCN         Aruba  35563.312500
# 1         SAS   Afghanistan   2057.062256
# 2         SSF        Angola   8036.690430
# 3         ECS       Albania  13724.058590
# 4         ECS       Andorra  43711.800780
# ..        ...           ...           ...
# 212       ECS        Kosovo   9723.561523
# 213       MEA   Yemen, Rep.   8269.671875
# 214       SSF  South Africa  12666.607420
# 215       SSF        Zambia   3201.289307
# 216       SSF      Zimbabwe   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.sample(5)
# Out:
#     region_id         country_name           gdp  \
# 141       SSF                Niger   1038.224121
# 117       ECS               Latvia  30982.173830
# 104       LCN  St. Kitts and Nevis  25569.357420
# 167       SSF                Sudan   4191.823242
# 109       SSF              Liberia   1333.422241
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 141                                    38.0                        NaN
# 117                                    46.7                       21.4
# 104                                    27.2                        8.1
# 167                                    51.4                        3.5
# 109                                     NaN                        NaN
#
#      composition_metal_percent  composition_other_percent  \
# 141                        1.0                       57.0
# 117                        2.6                        9.7
# 104                        8.8                       12.2
# ...

# %%
data.columns
# Out:
# Index(['region_id', 'country_name', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
# ...

# %%
gdp = data['gdp']

# %%
# df2=data.dropna().reset_index(drop=True)
# df2
data['region_id'][0]
# Out:
# 'LCN'

# %%
regions = data['region_id']
regions = set(regions)
regions = list(sorted(regions))
regions
# Out:
# ['EAS', 'ECS', 'LCN', 'MEA', 'NAC', 'SAS', 'SSF']

# %%
# qit'alar bo`yicha alohida data analiz qilamiz

# %% [markdown]
# ### Qit'alar bo`yicha

# %%
EAS = data[data['region_id']=='EAS']
ECS = data[data['region_id']=='ECS']
LCN = data[data['region_id']=='LCN']
MEA = data[data['region_id']=='MEA']
NAC = data[data['region_id']=='NAC']
SAS = data[data['region_id']=='SAS']
SSF = data[data['region_id']=='SSF']# har biri uchun alohida array ochamiz

# %% [markdown]
# ###### EAS qit'asi

# %%
EAS
# Out:
#     region_id              country_name            gdp  \
# 8         EAS            American Samoa   11113.442380
# 10        EAS                 Australia   47784.179690
# 28        EAS         Brunei Darussalam   60865.988280
# 36        EAS                     China   16092.300780
# 63        EAS                      Fiji   10787.685550
# 66        EAS     Micronesia, Fed. Sts.    3440.064209
# 80        EAS                      Guam   59074.941410
# 82        EAS      Hong Kong SAR, China   57215.968750
# 87        EAS                 Indonesia   10531.198240
# 98        EAS                     Japan   41309.957030
# 102       EAS                  Cambodia    3364.278809
# 103       EAS                  Kiribati    2249.768555
# 105       EAS               Korea, Rep.   42105.281250
# 107       EAS                   Lao PDR    6543.666992
# 118       EAS          Macao SAR, China  117335.585900
# 126       EAS          Marshall Islands    3628.895264
# ...

# %%
# Gross Domestic Product (GDP)
max_gdp = EAS['gdp'].max()
min_gdp = EAS['gdp'].min()
max_gdp,min_gdp
# Out:
# (117335.5859, 1093.788086)

# %%
EAS_GDP = EAS['gdp']/max_gdp
min_arg = EAS['gdp'].argmin()
max_arg = EAS['gdp'].argmax()
# EAS_GDP
EAS_GDP.iloc[[max_arg]]
# Out:
# 118    1.0
# Name: gdp, dtype: float64

# %%
EAS_GDP.plot()
# Out:
# <AxesSubplot:>

# %%
EAS_GDP.plot.pie(subplots=True, figsize=(10, 10))
# Out:
# array([<AxesSubplot:ylabel='gdp'>], dtype=object)
